# %%
# Importing the Libraries.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\abhis\\Downloads\\heart_failure_clinical_records_dataset.csv")
print(df)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
# Dataset and Columns description.

#1) Total Rows: 299

#2) Total Columns: 13

#3) Data Types: 10 integers, 3 floats


# Columns Description.

#1) age(float) :  Patient’s age(Years).

#2) anaemia(int) : Presence of anaemia(low red blood cell/hemoglobin count)i.e. 0 = No, 1 = Yes

#3) creatinine_phosphokinase(int) : Level of CPK enzyme in blood (mcg/L).

#4) diabetes(int) :  Whether patient has diabetes or not and in this column 0 = No, 1 = Yes

#5) ejection_fraction(int) :  Percentage of blood leaving the heart each contraction (%). Low values indicate heart failure risk.

#6) high_blood_pressure(int) :  0 = No, 1 = Yes.

#7) platelets(float) :  Platelet count in blood (kiloplatelets/mL).

#8) serum_creatinine(float) :  Level of serum creatinine in blood (mg/dL). Higher values suggest kidney dysfunction.

#9) serum_sodium(int) :  Level of sodium in blood (mEq/L).

#10) sex(int)  :  Patient’s biological sex. 0 = Female, 1 = Male

#11) smoking(int) :  Smoking status of the Patient. 0 = No, 1 = Yes.

#12) time(int) : Follow-up period (days).

#13) DEATH_EVENT(int) :  Whether patient died during the follow-up period. 0 = No, 1 = Yes.

# %% [markdown]
# ## EDA on this Dataset.

# %%
# Get the Quick Overview of the Dataset and Understand the structure of the Dataset.

print(df.shape)  # Rows and Columns of the Dataset.
print("Infornmation about the Dataset")
print(df.info()) # Complete Infornmation about the Columns of the Dataset.
print(df.columns) # Infornmation i.e. Names of the Columns about the Dataset.
print(df.head(5)) # Top 5 Rows of the Dataset.
print(df.tail(5)) # Last 5 Rows of the Dataset.
print(df.dtypes) # Getting Data - Types of each Column in the Dataset.
print(df.count())  # Count Non-Null Values in Each Column.
# Out:
# (299, 13)
# Infornmation about the Dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# ...

# %% [markdown]
# ## EDA on this Dataset.

# %%
# Get the Quick Overview of the Dataset and Understand the structure of the Dataset.

print(df.shape)  # Rows and Columns of the Dataset.
print(df.info)  # Complete Infornmation about the Dataset.
print(df.columns) # Infornmation i.e. Names of the Columns about the Dataset.
print(df.head(5)) # Top 5 Rows of the Dataset.
print(df.tail(5)) # Last 5 Rows of the Dataset.
print(df.dtypes) # Getting Data - Types of each Column in the Dataset.
print(df.count())  # Count Non-Null Values in Each Column.
# Out:
# (299, 13)
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
# Summary Statistics of the Dataset.

print(df.describe())  # Summary Statistics i.e. Mean, Min, Max etc. Values of all Numerical Columns in the Dataset.  
print(df.describe(include = 'all')) # Summary Statistics i.e. Mean, Min, Max etc. Values of all the Columns i.e. both Numerical and Categorical Columns in the Dataset.
print("Mean of high_blood_pressure Column: ", df['high_blood_pressure'].mean()) 
print("Median of high_blood_pressure Column: ", df['high_blood_pressure'].median()) 
print("Mode of high_blood_pressure Column: ", df['high_blood_pressure'].mode())
print("Variance of high_blood_pressure Column: ", df['high_blood_pressure'].var())
print("Minimum Value of battery_power Column: ", df['high_blood_pressure'].min())
print("Maximum Value of battery_power Column: ", df['high_blood_pressure'].max())
print("Quantile Values of high_blood_pressure Column: ", df['high_blood_pressure'].quantile([0.25, 0.5, 0.75]))
print("Correlation Matrix:\n", df.corr()) # Correlation Matrix of Each Column with the another column
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
# Checking for the Missing Vaues i.e. find out the Missing Values.

print(df.isnull()) # Null - Values in the form of Boolean Matrix(True - Missing Values , False - Not a mssing Values).
print(df.notnull()) # Opposite of isnull(True - Not a Missing Values , False - Missing Values)
print(df.isnull().sum()) # Count of the Missing Values of each Columns.

# By illustration, it is clear there are no missing values in any column in the Dataset.
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %%
# Handling Duplicates in the Dataset.

print(df.duplicated())  # Reurns a Boolean series i.e. True denotes Duplicate Value and False denotes Not a Duplicate Value.
print(df.duplicated().sum()) # Sum of the Duplicate Values in the Dataset.

# It is clear that there are no duplicate values in the Dataset.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Length: 299, dtype: bool
# 0

# %%
# Count the Unique Values of the Dataset.

print(df.nunique()) # Unique Values of each Column of the Dataset.
print(df.nunique().sum())  # Get unique count for the entire DataFrame.
print(df['high_blood_pressure'].nunique()) # Get unique count for a specific column.
# Out:
# age                          47
# anaemia                       2
# creatinine_phosphokinase    208
# diabetes                      2
# ejection_fraction            17
# high_blood_pressure           2
# platelets                   176
# serum_creatinine             40
# serum_sodium                 27
# sex                           2
# smoking                       2
# time                        148
# DEATH_EVENT                   2
# dtype: int64
# 675
# 2

# %%
# Univariate Analysis.

print(df['high_blood_pressure']. head(5)) # First Few values of the Particular Column.
print(df['high_blood_pressure']. tail(5)) # Last Few values of the Particular Column.
print(df['high_blood_pressure'].nunique()) # Get unique count for a specific column.
print(df['high_blood_pressure'].unique()) # Get unique values of a specific column.
print(df['high_blood_pressure'].describe()) # Statisical Analysis of a specific column.
median_value = df['high_blood_pressure'].median() # Median value of a specific column.
print("Median value of high_blood_pressure ", median_value)
print(df['high_blood_pressure'].value_counts()) # Counts how many times each unique value appears in that column.
# 0 and 1 are encoded values representing categories, commonly used for Binary Variables in datasets.
# 0 = No high blood pressure.
# 1 = Has high blood pressure.
plt.hist(df['high_blood_pressure'], bins=20, color='skyblue')
plt.xlabel('High blood Pressure')
plt.ylabel('Frequency')
plt.title('Histogram of High blood Pressure')
plt.show()

sns.boxplot(x=df['high_blood_pressure'])
plt.title('Boxplot of High blood Pressure')
plt.show()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: high_blood_pressure, dtype: int64
# 294    1
# 295    0
# 296    0
# 297    0
# 298    0
# Name: high_blood_pressure, dtype: int64
# 2
# [1 0]
# count    299.000000
# mean       0.351171
# std        0.478136
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: high_blood_pressure, dtype: float64
# Median value of high_blood_pressure  0.0
# high_blood_pressure
# 0    194
# 1    105
# Name: count, dtype: int64

# %%
# Bivariate Analysis.

print(df[['smoking', 'sex']].corr())  # Correlation between Two Variables. 
# Positive i.e. Males are more likely to smoke.
# Negative i.e. Females are more likely to smoke.
# Close to 0 i.e. No strong linear Relationship.
print(df.groupby('smoking')['sex'].describe()) # This gives mean, median, std deviation of each smoking for each sex group.
# Groups people by smoking status:
# smoking = 0 i.e. non-smokers
# smoking = 1 i.e. smokers
# Calculates stats for the sex column in each group:
# count i.e. how many people in each group
# mean i.e. proportion of males (since sex=1 is male)
# std, min, max, quartiles i.e. spread and distribution of sex
plt.figure(figsize=(6,4)) # Boxplot - To visually Compare Distribution.
sns.boxplot(x='smoking', y='sex', data=df, palette="Set2")
plt.title("Smoking vs Sex")
plt.xlabel("Smoking")
plt.ylabel("Sex")
plt.show()

# From correlation, descriptive stats, and boxplot:
# There is likely a higher proportion of males among smokers.
# Females are likely more represented among non-smokers.
# The relationship can be quantified with correlation (linear trend) or visually observed in the boxplot.
# Out:
#           smoking       sex
# smoking  1.000000  0.445892
# sex      0.445892  1.000000
#          count      mean       std  min  25%  50%  75%  max
# smoking
# 0        203.0  0.502463  0.501230  0.0  0.0  1.0  1.0  1.0
# 1         96.0  0.958333  0.200875  0.0  1.0  1.0  1.0  1.0
# C:\Users\abhis\AppData\Local\Temp\ipykernel_816\1566527467.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='smoking', y='sex', data=df, palette="Set2")

# %%
# Outliers Detection and Removing Outliers.

# Detect Outliers Using IQR.
Q1 = df['age'].quantile(0.25)  # 25th percentile
Q3 = df['age'].quantile(0.75)  # 75th percentile
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Any value below lower_bound or above upper_bound is considered an Outlier.

# Remove Outliers.

# Filter the dataset to remove Outliers.

df_clean = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]

print("Original dataset size:", df.shape)
print("Cleaned dataset size:", df_clean.shape)

# df_clean → dataset without outliers in battery_power.

# You can now use df_clean for analysis or modeling.


import seaborn as sns
import matplotlib.pyplot as plt

# Before removing outliers
plt.figure(figsize=(6,4))
sns.boxplot(x=df['age'])
plt.title("Age - Before Removing Outliers")
plt.show()

# After removing outliers
plt.figure(figsize=(6,4))
sns.boxplot(x=df_clean['age'])
plt.title("Age - After Removing Outliers")
plt.show()


# It is Clear from the Box - Plot , there are no Outliers in battery_power Column.
# Out:
# Lower Bound: 22.5
# Upper Bound: 98.5
# Original dataset size: (299, 13)
# Cleaned dataset size: (299, 13)

# %% [markdown]
# ## Feature Engineering on this Dataset.

# %%
#) Scaling / Normalization.

#1) Scaling (or Normalization) is a way of resizing your numbers so that all your features (columns) are on a similar scale.

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['age_scaled'] = scaler.fit_transform(df[['age']])
print(df['age_scaled'])
# Out:
# 0      0.636364
# 1      0.272727
# 2      0.454545
# 3      0.181818
# 4      0.454545
#          ...
# 294    0.400000
# 295    0.272727
# 296    0.090909
# 297    0.090909
# 298    0.181818
# Name: age_scaled, Length: 299, dtype: float64

# %%
# Binning / Discretization.

# Convert a Numerical Variable into Categories(bins). Useful for features like age, battery, price.

# Binning battery_power into 3 categories: Low, Medium, High.

df['high_blood_pressure_bin'] = pd.cut(df['high_blood_pressure'], bins=2, labels=['Low','High'])
print(df['high_blood_pressure_bin'])
# Out:
# 0      High
# 1       Low
# 2       Low
# 3       Low
# 4       Low
#        ...
# 294    High
# 295     Low
# 296     Low
# 297     Low
# 298     Low
# Name: high_blood_pressure_bin, Length: 299, dtype: category
# Categories (2, object): ['Low' < 'High']
